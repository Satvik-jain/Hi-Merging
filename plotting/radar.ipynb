# %%
import numpy as np
import matplotlib.pyplot as plt

# 数据准备
labels = ['M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10']
num_vars = len(labels)

# 模型数据
model1 = [90, 85, 80, 75, 70, 50, 50, 50, 50, 50]  # 左边5个表现好
model2 = [50, 50, 50, 50, 50, 70, 75, 80, 85, 90]  # 右边5个表现好
model3 = [85, 80, 85, 80, 85, 85, 80, 85, 80, 85]  # 两边都表现好

# 数据闭合
models = [model1, model2, model3]
for i in range(len(models)):
    models[i] += models[i][:1]  # 闭合曲线

angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # 闭合角度

# 调整旋转角度，让右边旋转两格（指标从 M9 开始）
angles = np.roll(angles, -2)  # -2 表示顺时针偏移两格
rotated_labels = np.roll(labels, -2)  # 确保标签顺时针对应

# 绘图
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# 绘制每个模型
colors = ['blue', 'green', 'red']
labels_models = ['Model1', 'Model2', 'Model3']
for model, color, label in zip(models, colors, labels_models):
    ax.fill(angles, model, color=color, alpha=0.25)  # 填充颜色
    ax.plot(angles, model, color=color, linewidth=2, label=label)  # 边界线

# 设置标签和样式
ax.set_xticks(angles[:-1])  # 不包括闭合点的角度
ax.set_xticklabels(rotated_labels, fontsize=10)  # 对应旋转后的标签
ax.set_yticks([20, 40, 60, 80, 100])
ax.set_yticklabels(['20', '40', '60', '80', '100'], color='grey', fontsize=8)
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))  # 图例

# 美化
ax.spines['polar'].set_visible(False)  # 隐藏边框
ax.grid(color='grey', linestyle='--', linewidth=0.5)
ax.set_title("Performance", fontsize=16)

# 显示
plt.tight_layout()
plt.show()

# %%
# Re-import necessary libraries after state reset
import numpy as np
import matplotlib.pyplot as plt

# Data preparation
labels = ['Metric 1', 'Metric 2', 'Metric 3', 'Metric 4', 'Metric 5',
          'Metric 6', 'Metric 7', 'Metric 8', 'Metric 9', 'Metric 10']
num_vars = len(labels)

# Model data
model1 = [90, 85, 80, 75, 70, 50, 50, 50, 50, 50]  # Strong on left 5 metrics
model2 = [50, 50, 50, 50, 50, 70, 75, 80, 85, 90]  # Strong on right 5 metrics
model3 = [85, 80, 85, 80, 85, 85, 80, 85, 80, 85]  # Strong on both sides

# Close the data loop
models = [model1, model2, model3]
for i in range(len(models)):
    models[i] += models[i][:1]  # Close the loop

angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # Close the loop for angles

# Plotting
fig, ax = plt.subplots(figsize=(8, 8), subplot_kw=dict(polar=True))

# Plot each model
colors = ['blue', 'green', 'red']
labels_models = ['Model 1: Strong on left', 'Model 2: Strong on right', 'Model 3: Balanced']
for model, color, label in zip(models, colors, labels_models):
    ax.fill(angles, model, color=color, alpha=0.25)  # Fill area
    ax.plot(angles, model, color=color, linewidth=2, label=label)  # Boundary line

# Set labels and styling
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=10)
ax.set_yticks([20, 40, 60, 80, 100])
ax.set_yticklabels(['20', '40', '60', '80', '100'], color='grey', fontsize=8)
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))  # Legend

# Aesthetic improvements
ax.spines['polar'].set_visible(False)  # Hide frame
ax.grid(color='grey', linestyle='--', linewidth=0.5)
# ax.set_title("Performance of Three Models Across 10 Metrics", fontsize=16)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Re-import necessary libraries after state reset
import numpy as np
import matplotlib.pyplot as plt

# Data preparation
labels = [
    "HealthCareMagic", "icliniq", "cord19", "health_advice",
    "medical_flashcards", "mediqa", "medqa", "pubmed",
    "wikidoc_patient_info", "wikidoc", "ChatMed_Consult", "MedChatZH"
]

# Model data from the updated table (original values)
pretrained = [28.7051, 19.3292, 39.1748, 2.8205, 22.7668, 17.3595, 37.3868, 5.7994, 18.785, 17.6217, 9.9138, 8.0654]
model1 = [30.3212, 26.5593, 40.7167, 97.7523, 41.1081, 32.052, 64.2862, 92.9898, 26.9203, 20.7237, 15.1218, 9.2714]
model2 = [33.3678, 27.332, 41.2026, 4.096, 29.85, 27.1442, 40.1598, 11.5017, 21.1528, 20.5808, 19.4513, 11.2665]
model3 = [31.6779, 28.7816, 39.6689, 97.755, 45.1714, 31.9421, 62.5711, 91.1692, 26.3293, 20.1695, 19.8074, 11.2958]

# Close the data loop for radar chart
models = [pretrained, model1, model2, model3]
for i in range(len(models)):
    models[i] += models[i][:1]

angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Plot each model
colors = ['purple', 'blue', 'green', 'red']
model_names = ['Pre-trained', 'Echelon-AI/Med-Qwen2-7B', 'shtdbb/qwen2-7b-med', 'Linear']
for model, color, name in zip(models, colors, model_names):
    ax.fill(angles, model, color=color, alpha=0.25)
    ax.plot(angles, model, color=color, linewidth=2, label=name)

# Set labels and ticks
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=9, rotation=30)
ax.set_yticks([20, 40, 60, 80, 100])  # Use consistent scale
ax.set_yticklabels(['20', '40', '60', '80', '100'], color='grey', fontsize=8)
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))

# Aesthetic improvements
ax.spines['polar'].set_visible(False)
ax.grid(color='grey', linestyle='--', linewidth=0.5)
# ax.set_title("Performance Comparison Across Datasets (Updated Models)", fontsize=16)

# Show plot
plt.tight_layout()



plt.show()

# %%
# Re-import necessary libraries after state reset
import numpy as np
import matplotlib.pyplot as plt

# Data preparation
labels = [
    "MedQA", "MediQA", "Medical Flashcards", "Health Advice",
    "Pubmed", "WikiDoc", "WikiDoc Patient", "CORD 19",
    "iCliniq", "HealthCareMagic", "ChatMed", "MedChatZH"
]

# Model data from the new table
pretrained = [20.0000] * len(labels)
model1 = [80.0000, 80.0000, 80.0000, 80.0000, 80.0000, 80.0000, 80.0000, 41.9833, 38.7931, 36.5743, 35.5833, 33.1770]
model2 = [25.7940, 55.8000, 43.1977, 21.3439, 25.8942, 76.5965, 44.8000, 80.0000, 80.0000, 80.0000, 80.0000, 80.0000]
model3 = [81.0000, 79.5000, 93.6279, 80.0027, 79.1794, 80.9649, 73.6000, 78.5000, 89.0690, 69.7030, 81.6667, 80.7965]

# Close the data loop for radar chart
models = [pretrained, model1, model2, model3]
for i in range(len(models)):
    models[i] += models[i][:1]

angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
angles += angles[:1]

# Plotting
fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# Define new colors for better aesthetics
colors = ['#f1c40f', '#3498db', '#e74c3c', '#8e44ad']
model_names = ['Qwen2-7B-Instruct', 'Echelon-AI/Med-Qwen2-7B', 'shtdbb/qwen2-7b-med', 'Hi-Merging']

# Plot each model
for model, color, name in zip(models, colors, model_names):
    ax.fill(angles, model, color=color, alpha=0.25)
    ax.plot(angles, model, color=color, linewidth=2, label=name)

# Set labels and ticks
ax.set_xticks(angles[:-1])
ax.set_xticklabels(labels, fontsize=13, rotation=30)
ax.set_yticks([20, 40, 60, 80, 100])  # Use consistent scale
ax.set_yticklabels(['20', '40', '60', '80', '100'], color='grey', fontsize=12)
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.2), fontsize=14)

# Aesthetic improvements
ax.spines['polar'].set_visible(False)
ax.grid(color='grey', linestyle='--', linewidth=0.5)

# Show plot
plt.tight_layout()


# 保存pdf
plt.savefig('data/4.pdf', bbox_inches='tight', pad_inches=0.1)
